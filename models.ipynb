# %%
import pandas as pd
import numpy as np

from pathlib import Path
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score

# %%
df = pd.read_csv(Path(r"D:/DOWNLOADS/breast canser project/breast_cancer_edited.csv"))

# Features and Target

X = df.drop("diagnosis", axis=1).values

diagnosis = df["diagnosis"]
if diagnosis.dtype == object:
    y = diagnosis.map({"B": 0, "M": 1}).values
else:
    y = diagnosis.astype(int).values

# %%
# Out:
# <class 'numpy.ndarray'>

# %%
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42)

scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %%
# KNN model
knn = KNeighborsClassifier(n_neighbors=5, n_jobs=-1)

# %%
knn.fit(X_train, y_train)

# %%
y_pred = knn.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 y_pred = knn.predict(X_test)
#
# Cell In[20], line 50, in KNN.predict(self, X)
#      47 predictions = []
#      49 for x in X:
# ---> 50     predictions.append(self.predict_one(x))
#      52 return np.array(predictions)
#
# Cell In[20], line 24, in KNN.predict_one(self, x)
#      21 # calculate distance
#      22 for i in range(len(self.X_train)):
# ---> 24     d = self.distance(x, self.X_train[i])
#      26     distances.append((d, self.y_train[i]))
#      28 # sort distances
#
# KeyboardInterrupt:

# %%
from sklearn.metrics import accuracy_score

knn_acc = accuracy_score(y_test, y_pred)
print("KNN Accuracy:", knn_acc)

# %%
dt = DecisionTreeClassifier(random_state=42)
dt.fit(X_train, y_train)
dt_pred = dt.predict(X_test)

dt_acc = accuracy_score(y_test, dt_pred)
print("Decision Tree Accuracy:", dt_acc)

# %%
rf = RandomForestClassifier(n_estimators=100, random_state=42)
rf.fit(X_train, y_train)
rf_pred = rf.predict(X_test)

rf_acc = accuracy_score(y_test, rf_pred)
print("Random Forest Accuracy:", rf_acc)

# %%
svm = SVC(kernel="linear")
svm.fit(X_train, y_train)
svm_pred = svm.predict(X_test)

svm_acc = accuracy_score(y_test, svm_pred)
print("SVM Accuracy:", svm_acc)

# %%
print("\n===== MODEL COMPARISON =====")
print("KNN Accuracy:", knn_acc)
print("Decision Tree Accuracy:", dt_acc)
print("Random Forest Accuracy:", rf_acc)
print("SVM Accuracy:", svm_acc)
